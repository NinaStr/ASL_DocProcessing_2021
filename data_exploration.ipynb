# %% [markdown]
# # Labeled Patent Dataset Exploration

# %% [markdown]
# ## 1. Notebook Configuration

# %% [markdown]
# ### 1.1. Loading Necessary Libraries

# %%
# General libraries:
import os
import glob
import numpy as np
import pandas as pd

# Dealing with images:
import cv2
import matplotlib.pyplot as plt

# Google APIs:
from google.cloud import bigquery

# Specific PDF libraries:
#!conda install -c conda-forge poppler
# !sudo apt-get install -y poppler-data
# !sudo apt-get install -y poppler-utils
# !pip install pdf2image
from pdf2image import convert_from_path
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# poppler-data is already the newest version (0.4.9-2).
# 0 upgraded, 0 newly installed, 0 to remove and 9 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libnspr4 libnss3 libpoppler82
# The following NEW packages will be installed:
#   libnspr4 libnss3 libpoppler82 poppler-utils
# 0 upgraded, 4 newly installed, 0 to remove and 9 not upgraded.
# Need to get 2962 kB of archives.
# After this operation, 8549 kB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian buster/main amd64 libnspr4 amd64 2:4.20-1 [112 kB]
# Get:2 http://deb.debian.org/debian buster/main amd64 libnss3 amd64 2:3.42.1-1+deb10u3 [1159 kB]
# Get:3 http://deb.debian.org/debian buster/main amd64 libpoppler82 amd64 0.71.0-5 [1507 kB]
# Get:4 http://deb.debian.org/debian buster/main amd64 poppler-utils amd64 0.71.0-5 [184 kB]
# Fetched 2962 kB in 0s (29.8 MB/s)
# Selecting previously unselected package libnspr4:amd64.
# (Reading database ... 81995 files and directories currently installed.)
# Preparing to unpack .../libnspr4_2%3a4.20-1_amd64.deb ...
# Unpacking libnspr4:amd64 (2:4.20-1) ...
# Selecting previously unselected package libnss3:amd64.
# Preparing to unpack .../libnss3_2%3a3.42.1-1+deb10u3_amd64.deb ...
# Unpacking libnss3:amd64 (2:3.42.1-1+deb10u3) ...
# Selecting previously unselected package libpoppler82:amd64.
# Preparing to unpack .../libpoppler82_0.71.0-5_amd64.deb ...
# Unpacking libpoppler82:amd64 (0.71.0-5) ...
# Selecting previously unselected package poppler-utils.
# Preparing to unpack .../poppler-utils_0.71.0-5_amd64.deb ...
# Unpacking poppler-utils (0.71.0-5) ...
# Setting up libnspr4:amd64 (2:4.20-1) ...
# Setting up libnss3:amd64 (2:3.42.1-1+deb10u3) ...
# Setting up libpoppler82:amd64 (0.71.0-5) ...
# Setting up poppler-utils (0.71.0-5) ...
# Processing triggers for man-db (2.8.5-2) ...
# Processing triggers for libc-bin (2.28-10) ...
# ldconfig: /usr/local/cuda-11.0/targets/x86_64-linux/lib/libcudnn_cnn_infer.so.8 is not a symbolic link
#
# ldconfig: /usr/local/cuda-11.0/targets/x86_64-linux/lib/libcudnn_ops_train.so.8 is not a symbolic link
#
# ldconfig: /usr/local/cuda-11.0/targets/x86_64-linux/lib/libcudnn_cnn_train.so.8 is not a symbolic link
#
# ldconfig: /usr/local/cuda-11.0/targets/x86_64-linux/lib/libcudnn_adv_train.so.8 is not a symbolic link
#
# ldconfig: /usr/local/cuda-11.0/targets/x86_64-linux/lib/libcudnn_adv_infer.so.8 is not a symbolic link
#
# ldconfig: /usr/local/cuda-11.0/targets/x86_64-linux/lib/libcudnn.so.8 is not a symbolic link
#
# ldconfig: /usr/local/cuda-11.0/targets/x86_64-linux/lib/libcudnn_ops_infer.so.8 is not a symbolic link
#
# ldconfig: /lib/libmyelin.so.1 is not a symbolic link
#
# ldconfig: /lib/libnvonnxparser.so.7 is not a symbolic link
#
# ldconfig: /lib/libnvinfer.so.7 is not a symbolic link
#
# ldconfig: /lib/libnvparsers.so.7 is not a symbolic link
#
# ldconfig: /lib/libnvinfer_plugin.so.7 is not a symbolic link
#
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ast (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ast (/opt/conda/lib/python3.7/site-packages)
# Requirement already satisfied: pdf2image in /opt/conda/lib/python3.7/site-packages (1.16.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.7/site-packages (from pdf2image) (8.3.1)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ast (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ast (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ast (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ast (/opt/conda/lib/python3.7/site-packages)

# %% [markdown]
# ### 1.2. Setting Notebook Inputs

# %%
# !gcloud config list
# Out:
# [ai]
# region = us-central1
# [core]
# account = 1971106428-compute@developer.gserviceaccount.com
# disable_usage_reporting = True
# project = qwiklabs-gcp-00-7b6f768bf42d
#
# Your active configuration is: [default]

# %%
PROJECT = 'qwiklabs-gcp-00-7b6f768bf42d'
REGION = 'us-central1'
BUCKET = 'labeled_patents'

os.environ['PROJECT'] = PROJECT
os.environ['REGION'] = REGION
os.environ['BUCKET'] = BUCKET

# %%
pd.set_option('expand_frame_repr', False)

# %% [markdown]
# ## 2. Loading the Labeled Patent Public Dataset Tables

# %% [markdown]
# ### 2.1. Creating the BigQuery Dataset

# %%
# %%bash
# # Create a BigQuery dataset for the labeled patents dataset if it doesn't exist:
# datasetexists=$(bq ls -d | grep -w labeled_patents)
#
# if [ -n "$datasetexists" ]; then
#     echo -e "BigQuery dataset already exists, let's not recreate it."
#     echo "Here are your current datasets:"
#     bq ls
# else
#     echo "Creating BigQuery dataset titled: labeled_patents"
#
#     bq --location=US mk --dataset \
#         --description "Labeled Patents" \
#         $PROJECT:labeled_patents
#     echo "Here are your current datasets:"
#     bq ls
# fi

# %%
# %%bigquery
# # Creating the "figures" table for object detection:
# CREATE OR REPLACE TABLE
#     labeled_patents.figures AS
# SELECT
#     *
# FROM
#     bigquery-public-data.labeled_patents.figures
# Out:
# Query complete after 0.00s: 100%|██████████| 3/3 [00:00<00:00, 1924.29query/s]
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# # Creating the "extracted_data" table for entity recognition:
# CREATE OR REPLACE TABLE
#     labeled_patents.extracted_data AS
# SELECT
#     *
# FROM
#     bigquery-public-data.labeled_patents.extracted_data
# Out:
# Query complete after 0.00s: 100%|██████████| 3/3 [00:00<00:00, 1964.55query/s]
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# # Creating the "invention_types" table document classification:
# CREATE OR REPLACE TABLE
#     labeled_patents.invention_types AS
# SELECT
#     *
# FROM
#     bigquery-public-data.labeled_patents.invention_types
# Out:
# Query complete after 0.00s: 100%|██████████| 3/3 [00:00<00:00, 2252.58query/s]
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 3. Exploring the Dataset Tables as Pandas Dataframes

# %%
# Creating a BigQuery client:
bq = bigquery.Client()

# %% [markdown]
# ### 3.1. Exploring "Figures" Table

# %%
# Loading "figures" table into a dataframe:
query = """
SELECT
    *
FROM
    labeled_patents.figures
"""
figures_df = bq.query(query).to_dataframe()
print('Dataset shape: {:d}x{:d}'.format(*figures_df.shape))
figures_df.head()
# Out:
# Dataset shape: 91x5
#                                             gcs_path  x_relative_min  \
# 0  gs://gcs-public-data--labeled-patents/espacene...        0.356322
# 1  gs://gcs-public-data--labeled-patents/espacene...        0.358137
# 2  gs://gcs-public-data--labeled-patents/espacene...        0.395039
# 3  gs://gcs-public-data--labeled-patents/espacene...        0.539020
# 4  gs://gcs-public-data--labeled-patents/espacene...        0.531155
#
#    y_relative_min  x_relative_max  y_relative_max
# 0        0.745275        0.669691        0.936856
# 1        0.637457        0.664247        0.935567
# 2        0.682131        0.640048        0.935567
# 3        0.600945        0.882638        0.955326
# 4        0.597079        0.888082        0.923110

# %%
# Number of unique values of the images:
n = figures_df['gcs_path'].unique().shape[0]
print('Number of unique images in "gcs_path" column: {:d}'.format(n))

figures_df.describe().transpose()
# Out:
# Number of unique images in "gcs_path" column: 91
#                 count      mean       std       min       25%       50%  \
# x_relative_min   91.0  0.384004  0.141596  0.124622  0.264670  0.335148
# y_relative_min   91.0  0.640960  0.066183  0.511168  0.584837  0.645189
# x_relative_max   91.0  0.800031  0.081475  0.625529  0.736237  0.798548
# y_relative_max   91.0  0.920575  0.046000  0.734107  0.906572  0.940722
#
#                      75%       max
# x_relative_min  0.534180  0.616455
# y_relative_min  0.699098  0.766323
# x_relative_max  0.883545  0.904416
# y_relative_max  0.950172  0.960052

# %% [markdown]
# The table "figures" has 91 rows (one per image). Each row contains one box coordinates and the image to which the box corresponds.
# Each row has five columns:
#  - gcs_path: image to which the box corresponds.
#  - x_relative_min: horizontal coordinate of the top left corner of the box, adimensionalized with image width.
#  - y_relative_min: vertical coordinate of the top left corner of the box, adimensionalized with image height.
#  - x_relative_max: horizontal coordinate of the bottom right corner of the box, adimensionalized with image width.
#  - y_relative_max: vertical coordinate of the bottom right corner of the box, adimensionalized with image height.

# %% [markdown]
# ### 3.2. Exploring "Invention_Types" Table

# %%
# Loading "figures" table into a dataframe:
query = """
SELECT
    *
FROM
    labeled_patents.invention_types
"""
invtypes_df = bq.query(query).to_dataframe()
print('Dataset shape: {:d}x{:d}'.format(*invtypes_df.shape))
invtypes_df.head()
# Out:
# Dataset shape: 136x2
#                                            gcs_path invention_type
# 0  gs://gcs-public-data--labeled-patents/us_057.pdf          other
# 1  gs://gcs-public-data--labeled-patents/us_051.pdf          other
# 2  gs://gcs-public-data--labeled-patents/us_074.pdf          other
# 3  gs://gcs-public-data--labeled-patents/us_058.pdf          other
# 4  gs://gcs-public-data--labeled-patents/us_064.pdf          other

# %%
aux_df = invtypes_df['invention_type'].value_counts()
# Out:
# other              76
# crypto             20
# med_tech           20
# computer_vision    20
# Name: invention_type, dtype: int64

# %%
# Number of unique values of the images:
n = invtypes_df['gcs_path'].unique().shape[0]
print('Number of unique images in "gcs_path" column: {:d}'.format(n))

print('Types of inventions of the documents: value + amount')
print(invtypes_df['invention_type'].value_counts())
# Out:
# Number of unique images in "gcs_path" column: 136
# Types of inventions of the documents: value + amount
# other              76
# crypto             20
# med_tech           20
# computer_vision    20
# Name: invention_type, dtype: int64

# %% [markdown]
# The table "inventions_type" has 136 rows (one per image). Each row contains the file name (and path) of the patent and the type of invention according to four types of inventions:
#  - crypto: 20 patents
#  - med_tech: 20 patents
#  - computer_vision: 20 patents
#  - others: 76 patents
#
# It is worth noting that there is information for 136 patents in this table, but we have only box coordinates in the "figures" table for 91 patents.

# %% [markdown]
# ### 3.3. Exploring "Extracted Data" Table

# %%
# Loading "extracted_data" table into a dataframe:
query = """
SELECT
    *
FROM
    labeled_patents.extracted_data
"""
extdata_df = bq.query(query).to_dataframe()
print('Dataset shape: {:d}x{:d}'.format(*extdata_df.shape))
extdata_df.head()
# Out:
# Dataset shape: 343x14
#                                             gcs_path issuer language  \
# 0  gs://gcs-public-data--labeled-patents/espacene...     EU       DE
# 1  gs://gcs-public-data--labeled-patents/espacene...     EU       DE
# 2  gs://gcs-public-data--labeled-patents/espacene...     EU       DE
# 3  gs://gcs-public-data--labeled-patents/espacene...     EU       DE
# 4  gs://gcs-public-data--labeled-patents/espacene...     EU       DE
#
#   publication_date class_international class_us application_number  \
# 0        29.08.018           E04H 6/12     None         18157874.1
# 1       03.10.2018          H01L 21/20     None         18166536.5
# 2       03.10.2018           G09B 9/04     None         18162935.3
# 3       03.10.2018           H05B 6/12     None         18165514.3
# 4       03.10.2018           H05B 6/12     None         18165513.5
#
#   filing_date priority_date_eu            representative_line_1_eu  \
# 0  21.02.2018       22.02.2017    Liedtke & Partner Patentanw√§lte
# 1  16.02.2016             None              Scheider, Sascha et al
# 2  20.03.2018       31.03.2017  v. Bezold & Partner Patentanw√§lte
# 3  03.04.2018       30.03.2017                                None
# 4  03.04.2018       30.03.2017                                None
#
#             applicant_line_1     inventor_line_1  \
# 0       SHB Hebezeugbau GmbH   VOLGER, Alexander
# 1  EV Group E. Thallner GmbH       Kurz, Florian
# 2         MAN Truck & Bus AG       Mohra, Holger
# 3       BSH Hausger√§te GmbH  Acero Acero, Jesus
# 4       BSH Hausger√§te GmbH  Acero Acero, Jesus
#
#                                         title_line_1           number
# 0     STEUERUNGSSYSTEM F√úR AUTOMATISCHE PARKH√ÑUSER  EP 3 366 869 A1
# 1              VORRICHTUNG ZUM BONDEN VON SUBSTRATEN  EP 3 382 744 A1
# 2  TECHNIK ZUR EINBEZIEHUNG EINER BEDIENUNGSANLEI...  EP 3 382 675 A1
# 3     VORRICHTUNG ZUR INDUKTIVEN ENERGIE√úBERTRAGUNG  EP 3 383 141 A2
# 4     VORRICHTUNG ZUR INDUKTIVEN ENERGIE√úBERTRAGUNG  EP 3 383 140 A1

# %%
print('Columns in the "extracted data" table:')
print(extdata_df.columns)
# Out:
# Columns in the "extracted data" table:
# Index(['gcs_path', 'issuer', 'language', 'publication_date',
#        'class_international', 'class_us', 'application_number', 'filing_date',
#        'priority_date_eu', 'representative_line_1_eu', 'applicant_line_1',
#        'inventor_line_1', 'title_line_1', 'number'],
#       dtype='object')

# %%
# Number of unique values of the images:
n = extdata_df['gcs_path'].unique().shape[0]
print('Number of unique images in "gcs_path" column: {:d}'.format(n))

# How many patents are from US and how many from EU?
print('Number of patents per issuer: US/EU')
print(extdata_df['issuer'].value_counts())

# How many patents are from language?
print('Number of patents per language')
print(extdata_df['language'].value_counts())
# Out:
# Number of unique images in "gcs_path" column: 343
# Number of patents per issuer: US/EU
# EU    246
# US     97
# Name: issuer, dtype: int64
# Number of patents per language
# EN    197
# FR     83
# DE     63
# Name: language, dtype: int64

# %%
# How format of some entities change depending on US/EU and language?
samp_n = 5
cols = ['gcs_path', 'language', 'class_us', 'class_international', 'application_number']

# Sample of US patents:
filtidx = extdata_df['issuer']=='US'
print(extdata_df.loc[filtidx, cols].head(samp_n))

# Sample of EU patents in English:
filtidx = (extdata_df['issuer']=='EU') & (extdata_df['language']=='EN')
print(extdata_df.loc[filtidx, cols].head(samp_n))
                         
# Sample of EU patents in French:
filtidx = (extdata_df['issuer']=='EU') & (extdata_df['language']=='FR')
print(extdata_df.loc[filtidx, cols].head(samp_n))

# Sample of EU patents in German:
filtidx = (extdata_df['issuer']=='EU') & (extdata_df['language']=='DE')
print(extdata_df.loc[filtidx, cols].head(samp_n))
# Out:
#                                              gcs_path language     class_us class_international application_number
# 163  gs://gcs-public-data--labeled-patents/us_006.pdf       EN    H04W 4/12           H04W 4/00         14/619,918
# 164  gs://gcs-public-data--labeled-patents/us_009.pdf       EN   H04S 7/303           H04R 5/02         15/568,451
# 165  gs://gcs-public-data--labeled-patents/us_007.pdf       EN   H04W 4/043          H04W 24/00         15/263,314
# 166  gs://gcs-public-data--labeled-patents/us_001.pdf       EN  H04W 64/003          H04W 64/00         15/679,694
# 167  gs://gcs-public-data--labeled-patents/us_005.pdf       EN    H04W 4/80           H04W 4/80         15/625,786
#                                              gcs_path language class_us class_international application_number
# 63  gs://gcs-public-data--labeled-patents/espacene...       EN     None          H04L 12/28         16924214.6
# 64  gs://gcs-public-data--labeled-patents/espacene...       EN     None           G06F 3/14         17882267.2
# 65  gs://gcs-public-data--labeled-patents/espacene...       EN     None           H04W 4/02         18182855.9
# 66  gs://gcs-public-data--labeled-patents/espacene...       EN     None           H04B 7/26           18179975
# 67  gs://gcs-public-data--labeled-patents/espacene...       EN     None          H04W 48/14         18178774.8
#                                               gcs_path language class_us class_international application_number
# 260  gs://gcs-public-data--labeled-patents/espacene...       FR     None          H04B 17/00         14200286.4
# 261  gs://gcs-public-data--labeled-patents/espacene...       FR     None          C12N 5/074         17305082.4
# 262  gs://gcs-public-data--labeled-patents/espacene...       FR     None          G06F 13/38         17168363.4
# 263  gs://gcs-public-data--labeled-patents/espacene...       FR     None          H04L 12/24         15182164.2
# 264  gs://gcs-public-data--labeled-patents/espacene...       FR     None           H04L 9/00         17153545.3
#                                             gcs_path language class_us class_international application_number
# 0  gs://gcs-public-data--labeled-patents/espacene...       DE     None           E04H 6/12         18157874.1
# 1  gs://gcs-public-data--labeled-patents/espacene...       DE     None          H01L 21/20         18166536.5
# 2  gs://gcs-public-data--labeled-patents/espacene...       DE     None           G09B 9/04         18162935.3
# 3  gs://gcs-public-data--labeled-patents/espacene...       DE     None           H05B 6/12         18165514.3
# 4  gs://gcs-public-data--labeled-patents/espacene...       DE     None           H05B 6/12         18165513.5

# %% [markdown]
# The table "extracted_data" has 343 rows (one per image). Each row contains the file name (and path) of the patent and the value of several entities of interest.
#
# In this table there are 246 patents from Europe and just 97 patents from the US. The distribution according to languages and issuer is shown next:
#  - US-EN:  97 patents
#  - EU-EN: 100 patents
#  - EU-FR:  83 patents
#  - EU-DE:  63 patents
#
# Another important aspect to take into account for entity extraction is that it seems that there is no rule that affects nor the application_number, neither the class_international depending on the issuer or language. Finally, another challenge will be distinguish between the "class_international" and "class_us" codes in the US patents, since it seems they have the same format.

# %%
# 4. Creating a Bucket to Store PDFs and CSVs

# %%
# %%bash
# ## Create GCS bucket if it doesn't exist already...
# exists=$(gsutil ls -d | grep -w gs://${BUCKET}/)
#
# if [ -n "$exists" ]; then
#     echo -e "Bucket exists, let's not recreate it."
#     echo "Here are your current buckets:"
#     gsutil ls
# else
#     echo "Creating a new GCS bucket."
#     gsutil mb -l ${REGION} gs://${BUCKET}
#     echo "Here are your current buckets:"
#     gsutil ls
# fi
# Out:
# Bucket exists, let's not recreate it.
# Here are your current buckets:
# gs://artifacts.qwiklabs-gcp-00-7b6f768bf42d.appspot.com/
# gs://cloud-ai-platform-56837b24-7d4e-4ad2-ae32-86a05972f71e/
# gs://labeled_patents/
# gs://qwiklabs-gcp-00-7b6f768bf42d/

# %% [markdown]
# ## 5. Copying the Patents PDFs into our Bucket and into Disk

# %%
# Copying pdfs into the project bucket:
# !gsutil -m cp gs://gcs-public-data--labeled-patents/*.pdf  gs://labeled_patents/pdf
# Out:
# Copying gs://gcs-public-data--labeled-patents/computer_vision_1.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_11.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_10.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_12.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_14.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_15.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_17.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_13.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_18.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_16.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_5.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_6.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_19.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_7.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_2.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_3.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_8.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_20.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_9.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/computer_vision_4.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_1.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_10.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_11.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_12.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_13.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_14.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_15.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_16.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_17.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_18.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_19.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_2.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_20.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_3.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_4.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_5.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_6.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_7.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_8.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/crypto_9.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de1.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de10.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de11.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de12.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de13.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de14.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de15.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de16.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de2.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de3.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de4.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de41.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de43.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de49.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de50.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de5.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de53.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de54.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de55.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de56.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de59.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de6.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de60.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de61.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de62.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de63.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de64.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de65.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de66.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de67.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de68.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de69.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de7.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de70.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de71.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de72.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de73.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de74.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de75.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de76.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de77.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de8.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de78.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de79.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de82.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de83.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de84.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de85.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de86.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de87.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de88.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de89.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de9.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de90.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de91.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de92.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de93.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de94.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de95.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de96.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de97.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de98.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_de99.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en1.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en10.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en100.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en11.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en12.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en13.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en14.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en16.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en15.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en17.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en18.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en19.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en2.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en20.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en21.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en22.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en23.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en24.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en25.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en26.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en27.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en28.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en29.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en3.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en31.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en30.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en32.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en33.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en34.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en35.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en36.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en37.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en38.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en39.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en4.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en40.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en41.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en42.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en43.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en44.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en45.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en46.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en47.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en48.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en49.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en5.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en50.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en51.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en53.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en52.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en54.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en55.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en56.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en57.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en58.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en59.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en6.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en60.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en61.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en62.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en63.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en64.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en65.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en66.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en67.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en69.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en68.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en7.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en70.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en71.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en72.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en73.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en74.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en75.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en76.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en77.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en78.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en79.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en8.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en80.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en81.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en82.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en83.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en84.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en85.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en86.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en87.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en88.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en89.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en9.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en90.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en91.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en92.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en93.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en94.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en95.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en97.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en96.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en98.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr1.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_en99.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr10.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr100.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr11.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr12.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr13.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr14.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr15.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr16.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr17.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr18.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr19.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr2.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr21.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr20.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr22.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr23.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr27.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr24.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr28.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr25.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr3.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr31.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr29.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr32.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr34.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr35.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr36.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr39.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr4.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr40.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr41.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr42.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr43.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr44.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr45.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr47.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr49.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr5.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr50.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr51.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr52.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr53.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr56.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr57.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr59.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr6.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr60.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr62.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr61.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr63.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr64.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr65.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr66.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr69.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr7.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr70.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr71.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr72.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr73.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr74.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr76.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr77.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr78.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr79.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr8.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr80.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr81.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr85.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr83.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr86.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr87.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr88.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr89.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr90.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr91.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr92.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr93.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr95.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr96.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr97.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr98.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/espacenet_fr99.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_1.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_10.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_11.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_12.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_13.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_14.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_15.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_17.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_16.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_18.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_19.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_2.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_20.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_3.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_4.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_5.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_6.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_7.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_8.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/med_tech_9.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_001.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_002.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_003.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_004.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_005.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_006.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_008.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_007.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_009.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_010.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_011.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_012.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_013.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_014.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_015.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_016.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_017.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_018.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_019.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_021.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_020.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_022.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_023.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_024.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_025.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_026.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_027.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_028.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_029.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_030.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_031.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_033.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_034.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_035.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_036.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_037.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_038.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_039.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_040.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_043.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_044.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_045.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_046.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_047.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_048.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_049.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_050.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_051.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_052.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_053.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_054.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_056.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_055.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_057.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_058.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_059.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_060.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_061.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_062.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_063.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_064.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_065.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_066.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_067.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_068.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_069.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_070.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_071.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_072.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_073.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_074.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_075.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_076.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_077.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_078.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_079.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_080.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_082.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_081.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_083.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_084.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_085.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_086.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_087.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_088.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_089.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_090.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_091.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_092.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_093.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_094.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_095.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_096.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_097.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_098.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_099.pdf [Content-Type=application/pdf]...
# Copying gs://gcs-public-data--labeled-patents/us_100.pdf [Content-Type=application/pdf]...
# | [403/403 files][ 19.7 MiB/ 19.7 MiB] 100% Done
# Operation completed over 403 objects/19.7 MiB.

# %%
# Create first a "dataset/pdf" folder:
# !gsutil -m cp gs://labeled_patents/pdf/*.pdf  ./dataset/pdf

# %%
import glob

pdf_lst = glob.glob("./dataset/pdf/*.pdf)

# %%
# !pip install pdf2image

import cv2
from pdf2image import convert_from_path
# Out:
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ast (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ast (/opt/conda/lib/python3.7/site-packages)
# Collecting pdf2image
#   Downloading pdf2image-1.16.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.7/site-packages (from pdf2image) (8.3.1)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ast (/opt/conda/lib/python3.7/site-packages)
# Installing collected packages: pdf2image
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ast (/opt/conda/lib/python3.7/site-packages)
# Successfully installed pdf2image-1.16.0
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ast (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ast (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-estimator (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -ast (/opt/conda/lib/python3.7/site-packages)

# %%
path = r'./dataset/pdf/computer_vision_1.pdf'
page_lst = convert_from_path(path)
print(page_lst)
# Out:
# [<PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1700x2200 at 0x7FCFA54F3910>]

# %%
for img in page_lst:
    img = np.array(img)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    
print('Image dimensions: {:d}x{:d}'.format(*img.shape))
print('Image pixel max. value: {:2.2f}'.format(img.max()))
print('Image pixel min. value: {:2.2f}'.format(img.min()))
# Out:
# Image dimensions: 2200x1700
# Image pixel max. value: 255.00
# Image pixel min. value: 0.00

# %%
h_fig = 12
w_fig = int(h_fig * img.shape[1] / img.shape[0])
plt.figure(figsize=(h_fig, w_fig))
plt.imshow(img, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 1699.5, 2199.5, -0.5)

# %% [markdown]
# ### X.X. Export from BigQuery to CSVs in GCS

# %%
# Construct a BigQuery client object.
client = bigquery.Client()

dataset_name = "babyweight"

# Create dataset reference object
dataset_ref = client.dataset(
    dataset_id=dataset_name, project=client.project)

# Export both train and eval tables
for step in ["train", "eval"]:
    destination_uri = os.path.join(
        "gs://", BUCKET, dataset_name, "data", "{}*.csv".format(step))
    table_name = "babyweight_data_{}".format(step)
    table_ref = dataset_ref.table(table_name)
    extract_job = client.extract_table(
        table_ref,
        destination_uri,
        # Location must match that of the source table.
        location="US",
    )  # API request
    extract_job.result()  # Waits for job to complete.

    print("Exported {}:{}.{} to {}".format(
        client.project, dataset_name, table_name, destination_uri))
